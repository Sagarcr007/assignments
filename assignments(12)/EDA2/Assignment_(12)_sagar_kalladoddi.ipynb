# %% [markdown]
# Data Exploration and Preprocessing:

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("/content/sample_data/adult_with_headers.csv")
data
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'income'],
#       dtype='object')

# %%
data.shape
# Out:
# (32561, 15)

# %%
data.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Length: 32561, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 24

# %%
data=data[data.duplicated()]
data
# Out:
#        age          workclass  fnlwgt      education  education_num  \
# 4881    25            Private  308144      Bachelors             13
# 5104    90            Private   52386   Some-college             10
# 9171    21            Private  250051   Some-college             10
# 11631   20            Private  107658   Some-college             10
# 13084   25            Private  195994        1st-4th              2
# 15059   21            Private  243368      Preschool              1
# 17040   46            Private  173243        HS-grad              9
# 18555   30            Private  144593        HS-grad              9
# 18698   19            Private   97261        HS-grad              9
# 21318   19            Private  138153   Some-college             10
# 21490   19            Private  146679   Some-college             10
# 21875   49            Private   31267        7th-8th              4
# 22300   25            Private  195994        1st-4th              2
# ...

# %%
data=data.drop_duplicates()
data
# Out:
#        age          workclass  fnlwgt      education  education_num  \
# 4881    25            Private  308144      Bachelors             13
# 5104    90            Private   52386   Some-college             10
# 9171    21            Private  250051   Some-college             10
# 11631   20            Private  107658   Some-college             10
# 13084   25            Private  195994        1st-4th              2
# 15059   21            Private  243368      Preschool              1
# 17040   46            Private  173243        HS-grad              9
# 18555   30            Private  144593        HS-grad              9
# 18698   19            Private   97261        HS-grad              9
# 21318   19            Private  138153   Some-college             10
# 21490   19            Private  146679   Some-college             10
# 21875   49            Private   31267        7th-8th              4
# 22367   44            Private  367749      Bachelors             13
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data
# Out:
#        age          workclass  fnlwgt      education  education_num  \
# 4881    25            Private  308144      Bachelors             13
# 5104    90            Private   52386   Some-college             10
# 9171    21            Private  250051   Some-college             10
# 11631   20            Private  107658   Some-college             10
# 13084   25            Private  195994        1st-4th              2
# 15059   21            Private  243368      Preschool              1
# 17040   46            Private  173243        HS-grad              9
# 18555   30            Private  144593        HS-grad              9
# 18698   19            Private   97261        HS-grad              9
# 21318   19            Private  138153   Some-college             10
# 21490   19            Private  146679   Some-college             10
# 21875   49            Private   31267        7th-8th              4
# 22367   44            Private  367749      Bachelors             13
# ...

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler,LabelEncoder
numerical_features=data.select_dtypes(include=['float64','int64']).columns
standard_scaler=StandardScaler()
data_standard_scaler=standard_scaled=data.copy()
data_standard_scaler[numerical_features]=standard_scaler.fit_transform(data[numerical_features])
print('\nStandard Scaled DataFrame:')
print(data_standard_scaler)
# Out:
# Standard Scaled DataFrame:
#             age          workclass    fnlwgt      education  education_num  \
# 4881  -0.540430            Private  1.242133      Bachelors       1.293993
# 5104   3.519583            Private -1.358711   Some-college       0.363936
# 9171  -0.790277            Private  0.651376   Some-college       0.363936
# 11631 -0.852738            Private -0.796641   Some-college       0.363936
# 13084 -0.540430            Private  0.101662        1st-4th      -2.116218
# 15059 -0.790277            Private  0.583415      Preschool      -2.426237
# 17040  0.771267            Private -0.129697        HS-grad       0.053916
# 18555 -0.228121            Private -0.421043        HS-grad       0.053916
# 18698 -0.915200            Private -0.902370        HS-grad       0.053916
# 21318 -0.915200            Private -0.486533   Some-college       0.363936
# 21490 -0.915200            Private -0.399831   Some-college       0.363936
# ...

# %%
min_max_scaler=MinMaxScaler()
data_min_max_scaler=data.copy()
data_min_max_scaler[numerical_features]=min_max_scaler.fit_transform(data[numerical_features])
print('\nMin-Max Scaled DataFrame:')
print(data_min_max_scaler.head())
# Out:
# Min-Max Scaled DataFrame:
#             age workclass    fnlwgt      education  education_num  \
# 4881   0.084507   Private  0.794252      Bachelors       0.923077
# 5104   1.000000   Private  0.061511   Some-college       0.692308
# 9171   0.028169   Private  0.627817   Some-college       0.692308
# 11631  0.014085   Private  0.219864   Some-college       0.692308
# 13084  0.084507   Private  0.472945        1st-4th       0.076923
#
#        marital_status        occupation    relationship                 race  \
# 4881    Never-married      Craft-repair   Not-in-family                White
# 5104    Never-married     Other-service   Not-in-family   Asian-Pac-Islander
# 9171    Never-married    Prof-specialty       Own-child                White
# 11631   Never-married      Tech-support   Not-in-family                White
# 13084   Never-married   Priv-house-serv   Not-in-family                White
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# ...

# %% [markdown]
# Encoding Techniques:

# %% [markdown]
# One-Hot Encoding

# %%
import pandas as pd
categorical_columns = data.select_dtypes(include=['object']).columns
# Apply One-Hot Encoding to categorical variables with less than 5 unique categories
for col in categorical_columns:
    if data[col].nunique() < 5:
        data= pd.get_dummies(data, columns=[col], prefix=[col], drop_first=True)
# Display the first few rows of the dataframe after One-Hot Encoding
print("\nDataFrame after One-Hot Encoding:")
print(data.head())

# %% [markdown]
# LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data.select_dtypes(include=['object']).columns
# Out:
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'sex', 'native_country', 'income'],
#       dtype='object')

# %%
workclass_uni=data['workclass'].unique()
education_uni=data['education'].unique()
marital_uni=data['marital_status'].unique()
occupation_uni=data['occupation'].unique()
relationship_uni=data['relationship'].unique()
race_uni=data['race'].unique()
sex_uni=data['sex'].unique()
native_uni=data['native_country'].unique()
income_uni=data['income'].unique()
print(workclass_uni)
print(education_uni)
print(marital_uni)
print(occupation_uni)
print(relationship_uni)
print(race_uni)
print(sex_uni)
print(native_uni)
print(income_uni)
# Out:
# [' Private' ' Self-emp-not-inc']
# [' Bachelors' ' Some-college' ' 1st-4th' ' Preschool' ' HS-grad'
#  ' 7th-8th' ' 5th-6th' ' Masters']
# [' Never-married' ' Married-civ-spouse' ' Divorced']
# [' Craft-repair' ' Other-service' ' Prof-specialty' ' Tech-support'
#  ' Priv-house-serv' ' Farming-fishing' ' Adm-clerical' ' Exec-managerial'
#  ' Handlers-cleaners' ' Machine-op-inspct']
# [' Not-in-family' ' Own-child' ' Husband' ' Unmarried']
# [' White' ' Asian-Pac-Islander' ' Black']
# [' Male' ' Female']
# [' Mexico' ' United-States' ' Guatemala' ' ?']
# [' <=50K' ' >50K']

# %%
workclass_count=data['workclass'].value_counts()
education_count=data['education'].value_counts()
marital_count=data['marital_status'].value_counts()
occupation_count=data['occupation'].value_counts()
relationship_count=data['relationship'].value_counts()
race_count=data['race'].value_counts()
sex_count=data['sex'].value_counts()
native_count=data['native_country'].value_counts()
income_count=data['income'].value_counts()
print(workclass_count)
print(education_count)
print(marital_count)
print(relationship_count)
print(race_count)
print(sex_count)
print(native_count)
print(income_count)
# Out:
#  Private             22
#  Self-emp-not-inc     1
# Name: workclass, dtype: int64
#  Some-college    9
#  HS-grad         7
#  Bachelors       2
#  1st-4th         1
#  Preschool       1
#  7th-8th         1
#  5th-6th         1
#  Masters         1
# Name: education, dtype: int64
#  Never-married         15
#  Married-civ-spouse     6
#  Divorced               2
# Name: marital_status, dtype: int64
#  Not-in-family    12
#  Husband           6
#  Own-child         4
#  Unmarried         1
# Name: relationship, dtype: int64
#  White                 20
#  Black                  2
#  Asian-Pac-Islander     1
# Name: race, dtype: int64
#  Male      15
#  Female     8
# Name: sex, dtype: int64
#  United-States    17
#  Mexico            4
#  Guatemala         1
#  ?                 1
# Name: native_country, dtype: int64
#  <=50K    21
#  >50K      2
# Name: income, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
data['Labels']=lb.fit_transform(data['workclass'])
data
# Out:
# <ipython-input-66-9dcd6bf3289d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Labels']=lb.fit_transform(data['workclass'])
#        age          workclass  fnlwgt      education  education_num  \
# 4881    25            Private  308144      Bachelors             13
# 5104    90            Private   52386   Some-college             10
# 9171    21            Private  250051   Some-college             10
# 11631   20            Private  107658   Some-college             10
# 13084   25            Private  195994        1st-4th              2
# 15059   21            Private  243368      Preschool              1
# 17040   46            Private  173243        HS-grad              9
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
data['Labels']=lb.fit_transform(data['education'])
data
# Out:
# <ipython-input-38-34d69d5e816d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Labels']=lb.fit_transform(data['education'])
#        age          workclass  fnlwgt      education  education_num  \
# 4881    25            Private  308144      Bachelors             13
# 5104    90            Private   52386   Some-college             10
# 9171    21            Private  250051   Some-college             10
# 11631   20            Private  107658   Some-college             10
# 13084   25            Private  195994        1st-4th              2
# 15059   21            Private  243368      Preschool              1
# 17040   46            Private  173243        HS-grad              9
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
data['Labels']=lb.fit_transform(data['education_num'])
data
# Out:
# <ipython-input-40-293862b83992>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Labels']=lb.fit_transform(data['education_num'])
#        age          workclass  fnlwgt      education  education_num  \
# 4881    25            Private  308144      Bachelors             13
# 5104    90            Private   52386   Some-college             10
# 9171    21            Private  250051   Some-college             10
# 11631   20            Private  107658   Some-college             10
# 13084   25            Private  195994        1st-4th              2
# 15059   21            Private  243368      Preschool              1
# 17040   46            Private  173243        HS-grad              9
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
data['Labels']=lb.fit_transform(data['occupation'])
data
# Out:
# <ipython-input-67-b8437a137c26>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Labels']=lb.fit_transform(data['occupation'])
#        age          workclass  fnlwgt      education  education_num  \
# 4881    25            Private  308144      Bachelors             13
# 5104    90            Private   52386   Some-college             10
# 9171    21            Private  250051   Some-college             10
# 11631   20            Private  107658   Some-college             10
# 13084   25            Private  195994        1st-4th              2
# 15059   21            Private  243368      Preschool              1
# 17040   46            Private  173243        HS-grad              9
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
data['Labels']=lb.fit_transform(data['capital_gain'])
data
# Out:
# <ipython-input-42-0784c7c6ec8b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Labels']=lb.fit_transform(data['capital_gain'])
#        age          workclass  fnlwgt      education  education_num  \
# 4881    25            Private  308144      Bachelors             13
# 5104    90            Private   52386   Some-college             10
# 9171    21            Private  250051   Some-college             10
# 11631   20            Private  107658   Some-college             10
# 13084   25            Private  195994        1st-4th              2
# 15059   21            Private  243368      Preschool              1
# 17040   46            Private  173243        HS-grad              9
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
data['Labels']=lb.fit_transform(data['capital_loss'])
data
# Out:
# <ipython-input-43-f35f5b229d6a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Labels']=lb.fit_transform(data['capital_loss'])
#        age          workclass  fnlwgt      education  education_num  \
# 4881    25            Private  308144      Bachelors             13
# 5104    90            Private   52386   Some-college             10
# 9171    21            Private  250051   Some-college             10
# 11631   20            Private  107658   Some-college             10
# 13084   25            Private  195994        1st-4th              2
# 15059   21            Private  243368      Preschool              1
# 17040   46            Private  173243        HS-grad              9
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
data['Labels']=lb.fit_transform(data['hours_per_week'])
data
# Out:
# <ipython-input-44-458eb9885bbd>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Labels']=lb.fit_transform(data['hours_per_week'])
#        age          workclass  fnlwgt      education  education_num  \
# 4881    25            Private  308144      Bachelors             13
# 5104    90            Private   52386   Some-college             10
# 9171    21            Private  250051   Some-college             10
# 11631   20            Private  107658   Some-college             10
# 13084   25            Private  195994        1st-4th              2
# 15059   21            Private  243368      Preschool              1
# 17040   46            Private  173243        HS-grad              9
# ...

# %%
import matplotlib.pyplot as plt
# Plot histogram to visualize the distribution
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.hist(data['fnlwgt'], bins=10, edgecolor='black')
plt.title('Histogram of Skewed Feature')
plt.xlabel('Values')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Apply log transformation
import numpy as np
data['log_feature1'] = np.log(data['fnlwgt'])
data['log_feature1']
# Out:
# <ipython-input-69-adb38add8fe5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['log_feature1'] = np.log(data['fnlwgt'])
# 4881     12.638322
# 5104     10.866395
# 9171     12.429420
# 11631    11.586715
# 13084    12.185839
# 15059    12.402330
# 17040    12.062451
# 18555    11.881678
# 18698    11.485153
# 21318    11.836117
# 21490    11.896002
# 21875    10.350319
# 22367    12.815156
# 22494    10.680033
# 25872    12.388965
# 26313    12.523358
# 28230    12.451299
# 28522    12.227027
# 28846    10.339029
# 29157    12.241449
# 30845    11.802725
# 31993    12.435512
# 32404    12.847819
# Name: log_feature1, dtype: float64

# %%
# Plot histogram of log-transformed feature
plt.subplot(1, 2, 2)
plt.hist(data['log_feature1'], bins=10, edgecolor='black')
plt.title('Histogram of Log-Transformed Feature')
plt.xlabel('Log Values')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
categorical_columns = data.select_dtypes(include=['object']).columns
# Apply One-Hot Encoding to categorical variables with less than 5 unique categories
for col in categorical_columns:
    if data[col].nunique() < 5:
        data= pd.get_dummies(data, columns=[col], prefix=[col], drop_first=True)
# Display the first few rows of the dataframe after One-Hot Encoding
print("\nDataFrame after One-Hot Encoding:")
print(data.head())
# Out:
# DataFrame after One-Hot Encoding:
#        age  fnlwgt      education  education_num        occupation  \
# 4881    25  308144      Bachelors             13      Craft-repair
# 5104    90   52386   Some-college             10     Other-service
# 9171    21  250051   Some-college             10    Prof-specialty
# 11631   20  107658   Some-college             10      Tech-support
# 13084   25  195994        1st-4th              2   Priv-house-serv
#
#        capital_gain  capital_loss  hours_per_week  Labels  log_feature1  ...  \
# 4881              0             0              40       1     12.638322  ...
# 5104              0             0              35       6     10.866395  ...
# 9171              0             0              10       8     12.429420  ...
# 11631             0             0              10       9     11.586715  ...
# 13084             0             0              40       7     12.185839  ...
#
#        relationship_ Not-in-family  relationship_ Own-child  \
# ...

# %% [markdown]
# IsolationForest

# %%
from sklearn.ensemble import IsolationForest
# Identify outliers using Isolation Forest
clf = IsolationForest(contamination=0.05, random_state=42)
outlier_preds = clf.fit_predict(data.dropna())
# Create a mask to identify outliers
outlier_mask = outlier_preds == -1
# Remove outliers from the dataframe
data_no_outliers = data.loc[~outlier_mask]
# Display the dataframe after removing outliers
print("\nDataFrame after removing outliers:")
data_no_outliers
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-995052e67160> in <cell line: 4>()
#       2 # Identify outliers using Isolation Forest
#       3 clf = IsolationForest(contamination=0.05, random_state=42)
# ----> 4 outlier_preds = clf.fit_predict(data.dropna())
#       5 # Create a mask to identify outliers
#       6 outlier_mask = outlier_preds == -1
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in fit_predict(self, X, y)
#     995         """
#     996         # override for transductive outlier detectors like LocalOulierFactor
# --> 997         return self.fit(X).predict(X)
#     998
#     999
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_iforest.py in fit(self, X, y, sample_weight)
#     288         """
#     289         self._validate_params()
# ...

# %% [markdown]
# PPS score

# %%
# !pip install -U ppscore

# %%
import ppscore as pps
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-6420d2c1020f> in <cell line: 1>()
# ----> 1 import ppscore as pps
#
# ModuleNotFoundError: No module named 'ppscore'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
pps_score=pps.matrix(data)
pps_score
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# ...

# %%
import ppscore as pps
import pandas as pd
data =pd.read_csv("/content/sample_data/adult_with_headers.csv")
data_encoded=pd.get_dummies(data)
data_encoded
# Out:
#        age  fnlwgt  education_num  capital_gain  capital_loss  hours_per_week  \
# 0       39   77516             13          2174             0              40
# 1       50   83311             13             0             0              13
# 2       38  215646              9             0             0              40
# 3       53  234721              7             0             0              40
# 4       28  338409             13             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 32556   27  257302             12             0             0              38
# 32557   40  154374              9             0             0              40
# 32558   58  151910              9             0             0              40
# 32559   22  201490              9             0             0              20
# 32560   52  287927              9         15024             0              40
#
# ...

# %%
pps.matrix(data)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# ...

# %%
import seaborn as sns
correlation_matrix = data.corr(numeric_only=True)

# Display the correlation matrix
print("\nCorrelation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                                          age    fnlwgt  education_num  \
# age                                 1.000000 -0.351317       0.125960
# fnlwgt                             -0.351317  1.000000       0.168972
# education_num                       0.125960  0.168972       1.000000
# capital_gain                             NaN       NaN            NaN
# capital_loss                             NaN       NaN            NaN
# hours_per_week                      0.260277  0.159010      -0.260288
# Labels                             -0.064573  0.430514       0.143824
# log_feature1                       -0.466046  0.939653       0.136148
# workclass_ Self-emp-not-inc         0.204385 -0.308989       0.077591
# marital_status_ Married-civ-spouse  0.377800 -0.428575      -0.060058
# marital_status_ Never-married      -0.426407  0.263695       0.017227
# relationship_ Not-in-family        -0.091477  0.385507      -0.105588
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
